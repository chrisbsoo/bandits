# %%
import src.models.stochastic as stc
import numpy as np

np.random.seed(123)

K = 10
T = 100
p = [0.4]*9 + [0.9]
pa = [0.7]*10

model = stc.bernoulli_model(K, T)
model.gen_bern(p)
model.genact_bern(pa)

# %%
# CONSOLE

# %%
import src.algos.UCB1 as ucb1

policy = ucb1.simple_ucb1(model)
policy.eval(n_runs=100, sleeping=False)
# Out:
# ⠏: [XXXXXXXXX-] (99 / 100) | ⠏: [XXXXXXXXX-] (99 / 100)
