# %%
import src.models.stochastic as stc
import numpy as np

np.random.seed(123)

K = 10
T = 10000
p = [0.4]*9 + [0.9]

model = stc.bernoulli_model(K, T)
model.gen_bern(p)

# %%
import src.algos.UCB1 as ucb1

policy = ucb1.simple_ucb1(model)
policy.eval(n_runs=10, sleeping=False)
# Out:
# ⠏: [XXXXXXXXX-] (9 / 10) | ⠏: [XXXXXXXXX-] (9999 / 10000)

# %%
pa = [0.7]*10
model.genact_bern(pa)

policy.eval(n_runs=10)
# Out:
# ⠋: [----------] (0 / 10) | ⠋: [----------] (10 / 10000)
# ⠏: [XXXXXXXXX-] (9 / 10) | ⠏: [XXXXXXXXX-] (9999 / 10000)
